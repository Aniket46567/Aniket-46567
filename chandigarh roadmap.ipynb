# %%
print("===================================================")
print("        ❤️WELCOME TO CHANDIGARH(TRICITY)❤️")
print("===================================================")

print("\nCHANDIGARH IS DIVIDED INTO NINE PHASES/ZONES:")
print("\nPlease select the phase/zone where you want to visit:-")

print("1. Phase 1 - Sector 1 to 30")
print("2. Phase 2 - Sector 31 to 47")
print("3. Phase 3 - Sector 48 to 56")
print("4. Industrial Area Phase 1")
print("5. Industrial Area Phase 2")
print("6. Rajiv Gandhi Chandigarh Technology Park (IT Park)")
print("7. North-East Zone")
print("8. South-East Zone")
print("9. Urban/Historical Villages")

select = int(input("\nEnter the phase/zone number(1-9): "))

if select == 1:
    
    sector = int(input("Enter sector number (1-30): "))
    
    if sector >= 1 and sector <= 30:
        
        if sector == 13:
            print("There is no any sector 13 in chandigarh because number 13 is unlucky.")

        elif sector == 7 or sector == 8:
            block = input("Enter sector block (A/B/C): ").upper()

            if block == "A" or block == "B" or block == "C":
                print("You want to visit Sector", sector, block)
            else:
                print("There is no any sector",sector, block)

        else:
            block = input("Enter sector block (A/B/C/D): ").upper()

            if block == "A" or block == "B" or block == "C" or block == "D":
                print("You want to visit Sector", sector, block)
            else:
                print("There is no any sector",sector, block)

    else:
        print("There is no any sector in Phase 1.")

elif select == 2:

    sector = int(input("Enter sector number (31-47): "))

    if sector >= 31 and sector <= 47:

        block = input("Enter sector block (A/B/C/D): ").upper()

        if block == "A" or block == "B" or block == "C" or block == "D":
            print("You want to visit Sector", sector, block)
        else:
            print("There is no any sector",sector, block)

    else:
        print("There is no any sector in Phase 2.")

elif select == 3:

    sector = int(input("Enter sector number (48-56): "))

    if sector >= 48 and sector <= 56:

        block = input("Enter sector block (A/B/C/D): ").upper()

        if block == "A" or block == "B" or block == "C" or block == "D":
            print("You want to visit Sector", sector, block)
        else:
            print("There is no any sector",sector, block)

    else:
        print("There is no any sector in Phase 3.")
        
elif select == 4:

    print("You want to visit Industrial Area Phase 1.")

elif select == 5:

    print("You want to visit Industrial Area Phase 2.")

elif select == 6:

    print("You want to visit Rajiv Gandhi Chandigarh Technology Park.")
    print("It is also known as Chandigarh IT Park.")

elif select == 7:

    print("\nNorth-East Zone:-")
    print("1.Bapu Dham Colony")
    print("2.Indira Colony")
    print("3.Housing Board Complex")
    print("4.Manimajra")
    print("5.Mauli Jagran")
    print("6.Kishangarh")

    area = input("\nEnter the number of place you want to visit: ")

    if area == "1":
        print("You want to visit Bapu Dham Colony.")
    elif area == "2":
        print("You want to visit Indira Colony.")
    elif area == "3":
        print("You want to visit Housing Board Complex")
    elif area == "4":
        print("You want to visit Manimajra.")
    elif area == "5":
        print("You want to visit Mauli Jagran.")
    elif area == "6":
        print("You want to visit Kishangarh.")
    else:
        print("There is no such area in North-East Zone.")

elif select == 8:

    print("\nSouth-East Zone:-")
    print("1.Colony No. 4")
    print("2.Hallomajra")
    print("3.Karsan")
    print("4.Daria")
    print("5.Makhan Majra")
    print("6.Raipur Khurd")
    print("7.Raipur Kalan")

    area = input("\nEnter the number of place you want to visit: ")

    if area == "1":
        print("You want to visit Colony No. 4.")
    elif area == "2":
        print("You want to visit Hallomajra.")
    elif area == "3":
        print("You want to visit Karsan.")
    elif area == "4":
        print("You want to visit Daria.")
    elif area == "5":
        print("You want to visit Makhan Majra.")
    elif area == "6":
        print("You want to visit Raipur Khurd.")
    elif area == "7":
        print("You want to visit Raipur Kalan.")
    else:
        print("There is no such area in South-East Zone.")

elif select == 9:

    print("\nUrban/Historical Villages:-")
    print("1.Burail")
    print("2.Maloya")
    print("3.Kajheri")
    print("4.Attawa")
    print("5.Badheri")
    print("6.Buterla")
    print("7.Palsora")

    area = input("\nEnter the number of village you want to visit: ")

    if area == "1":
        print("You want to visit Burail.")
    elif area == "2":
        print("You want to visit Maloya.")
    elif area == "3":
        print("You want to visit Kajheri.")
    elif area == "4":
        print("You want to visit Attawa.")
    elif area == "5":
        print("You want to visit Badheri.")
    elif area == "6":
        print("You want to visit Buterla.")
    elif area == "7":
        print("You want to visit Palsora.")
    else:
        print("There is no such Village exist.")
        
else:
    print("❌YOU HAVE ENTERED THE WRONG DETAILS.❌")
    print("Please enter a number from 1 to 9.")


print("\n========================================")
print("       ❤️THANKYOU FOR VISITING❤️")
print("========================================")
# Out:
# ...
#         ❤️WELCOME TO CHANDIGARH(TRICITY)❤️
# ...
#
# CHANDIGARH IS DIVIDED INTO NINE PHASES/ZONES:
#
# Please select the phase/zone where you want to visit:-
# 1. Phase 1 - Sector 1 to 30
# 2. Phase 2 - Sector 31 to 47
# 3. Phase 3 - Sector 48 to 56
# 4. Industrial Area Phase 1
# 5. Industrial Area Phase 2
# 6. Rajiv Gandhi Chandigarh Technology Park (IT Park)
# 7. North-East Zone
# 8. South-East Zone
# 9. Urban/Historical Villages
# Enter the phase/zone number(1-9):  10
# ❌YOU HAVE ENTERED THE WRONG DETAILS.❌
# Please enter a number from 1 to 9.
#
# ...
#        ❤️THANKYOU FOR VISITING❤️
# ...
